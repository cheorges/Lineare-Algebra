# %% [markdown]
# # Matrizen in Python
# ## Sandbox

# %%
def scalarVectorMult(x, A):
    return [x * a for a in A]

# %%
def scalarMatrixMult(x, A):
    return [scalarVectorMult(x, row) for row in A]

# %% [markdown]
# ### Matrixmultiplikation

# %%
import numpy as np

A = np.array( ((2,3),(3,5)) )
B = np.matrix( ((1,2),(5,-1)) )

np.dot(A, B)
# Out:
# matrix([[17,  1],
#         [28,  1]])

# %%
A = np.matrix( ((1,2,-3,1),(5,0,6,1)) ) # 2x4
B = np.matrix( ((1,8,-1),(0,0,1),(0.5,-1,-2),(-1,0,4)) ) # 4x3
np.dot(A, B) # OK -> 2x4 = 4x3

"""
np.dot(B, A) # Nicht OK - > 4x2 = 3x4
"""
# Out:
# '\nnp.dot(B, A) # Nicht OK - > 4x2 = 3x4\n'

# %% [markdown]
# ### Spiegelt die Matrix an der Hauptdiagonale

# %%
A = np.matrix( ((1,2,-3,1),(5,0,6,1)) ) # 2x4
A.transpose()
# Out:
# matrix([[ 1,  5],
#         [ 2,  0],
#         [-3,  6],
#         [ 1,  1]])

# %% [markdown]
# ### Matrix invertieren

# %%
from numpy.linalg import inv
A = np.matrix( ((1,2,1),(4,2,4),(1,2,3)) )
inv(A)
# Out:
# matrix([[ 0.16666667,  0.33333333, -0.5       ],
#         [ 0.66666667, -0.16666667,  0.        ],
#         [-0.5       ,  0.        ,  0.5       ]])

# %%
A * inv(A) # Ergibt die Einheitsmatrix
# Out:
# matrix([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]])

# %% [markdown]
# ### Matrizen mit Sympy rechnen

# %%
from sympy import *

# %%
init_printing()

# %%
A = Matrix([[1,2,3],[4,5,6],[7,8,9]])
A
# Out:
# ⎡1  2  3⎤
# ⎢       ⎥
# ⎢4  5  6⎥
# ⎢       ⎥
# ⎣7  8  9⎦

# %%
# Transportieren
A.T
# Out:
# ⎡1  4  7⎤
# ⎢       ⎥
# ⎢2  5  8⎥
# ⎢       ⎥
# ⎣3  6  9⎦

# %%
B = Matrix([[2,2,2],[3,3,3],[4,4,4]])
A * B, B * A
# Out:
# ⎛⎡20  20  20⎤  ⎡24  30  36⎤⎞
# ⎜⎢          ⎥  ⎢          ⎥⎟
# ⎜⎢47  47  47⎥, ⎢36  45  54⎥⎟
# ⎜⎢          ⎥  ⎢          ⎥⎟
# ⎝⎣74  74  74⎦  ⎣48  60  72⎦⎠

# %%
# Wichtige Rechenregel!!!
(A * B).T, B.T * A.T
# Out:
# ⎛⎡20  47  74⎤  ⎡20  47  74⎤⎞
# ⎜⎢          ⎥  ⎢          ⎥⎟
# ⎜⎢20  47  74⎥, ⎢20  47  74⎥⎟
# ⎜⎢          ⎥  ⎢          ⎥⎟
# ⎝⎣20  47  74⎦  ⎣20  47  74⎦⎠

# %%
A = Matrix([[1,2,1],[4,2,4],[1,2,3]])
A.inv()
# Out:
# ⎡1/6   1/3   -1/2⎤
# ⎢                ⎥
# ⎢2/3   -1/6   0  ⎥
# ⎢                ⎥
# ⎣-1/2   0    1/2 ⎦

# %%
A * A.inv() # Ergibt die Einheitsmatrix
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  1  0⎥
# ⎢       ⎥
# ⎣0  0  1⎦

# %% [markdown]
# ## Lineare Gleichungssysteme
# ### Gauss-Verfahren

# %%
M = [[1,2,3],[4,5,6],[1,1,1]]
M
# Out:
# [[1, 2, 3], [4, 5, 6], [1, 1, 1]]

# %%
def rowMod(M, i, j, factor):
    """
    Elementare Zeilenumformung Type 3
    Addiere zur i-ten Zweile das x-fache der j-ten Zeile
    M wird modifiziert!
    """
    M[i] = [a + factor * b for a, b in zip(M[i], M[j])]

# %%
rowMod(M, 0, 1, 3)
M
# Out:
# [[13, 17, 21], [4, 5, 6], [1, 1, 1]]

# %%
"""
Umwandeln in ZSF
"""
def rowEchelon(M):
    row, col = 0, 0
    rows, cols = len(M), len(M[0])
    while row < rows and col < cols:
        # versuche, Pivotelement zu finden
        if M[row][col] == 0:
            # die Zeilen unter row durchgehen:
            for r in range(row + 1, rows):
                if M[r][col] != 0:
                    rowMod(M, row, r, 1)
                    break
        if M[row][col] == 0:
            col += 1
            continue
        pivot = M[row][col]
        for r in range(row + 1, rows):
            if M[r][col] != 0:
                rowMod(M, r, row, -M[r][col] / pivot)
        row += 1
        col += 1

# %%
M = [[1,2,3],[4,5,6],[-3,0,12]]
rowEchelon(M)
M
# Out:
# [[1, 2, 3], [0.0, -3.0, -6.0], [0.0, 0.0, 9.0]]

# %%
# Achtung Fliesskomaarithmetik
M = [[6,-1,-1,4],[1,1,10,-6],[2,-1,1,-2]]
rowEchelon(M)
M
# Out:
# [[6, -1, -1, 4], [0.0, 1.1666666666666667, 10.166666666666666, -6.666666666666
# 667], [0.0, 1.1102230246251565e-16, 7.142857142857143, -7.142857142857143]]

# %%
# Nur zum Aufzeigen
"""
def identityMatrix(n):
    E = [[0] * n for i in range(n)]
    for i in range(n):
        E[i][i] = 1
    return E

def type3Matrix(n, i, j, factor):
    A = identityMatrix(n)
    A[i][j] = x
    return A

def rowMod(M, i, j, factor):
    return matrixProd(type3Matrix(len(M), i, j, factor), M)
"""
# Out:
# '\ndef identityMatrix(n):\n    E = [[0] * n for i in range(n)]\n    for i in range(n):\n        E[i][i] = 1\n    return E\n\ndef type3Matrix(n, i, j, factor):\n    A = identityMatrix(n)\n    A[i][j] = x\n    return A\n\ndef rowMod(M, i, j, factor):\n    return matrixProd(type3Matrix(len(M), i, j, factor), M)\n'

# %% [markdown]
# ## Determinante berechnen

# %%
def determinant(M):
    rowEchelon(M)
    det = 1
    for i in range(len(M)):
        det *= M[i][i]
    return det

M = [[6,-1,-1],[1,1,10],[2,-1,1]]
determinant(M)
# Out:
# 50.0

# %% [markdown]
# ### Mit Sympy

# %%
from sympy import *
A = Matrix([[6,-1,-1,4],[1,1,10,-6],[2,-1,1,-2]])
A.rref()
# Out:
# ⎛⎡1  0  0  1 ⎤           ⎞
# ⎜⎢           ⎥           ⎟
# ⎜⎢0  1  0  3 ⎥, (0, 1, 2)⎟
# ⎜⎢           ⎥           ⎟
# ⎝⎣0  0  1  -1⎦           ⎠

# %%
from sympy.abc import x, y, z
linsolve(A, [x,y,z])
# Out:
# {(1, 3, -1)}

# %%
C = Matrix([[6,-1,-1],[1,1,10],[2,-1,1]])
b = Matrix([4,-6,-2])
linsolve((C,b), [x,y,z])
# Out:
# {(1, 3, -1)}

# %%
A = Matrix([[6,-1,-1],[1,1,10],[2,-1,1]])
A.det()
# Out:
# 50

# %%
A = Matrix([[6,-1,-1],[1,1,10],[2,-1,1]])
A.inv()
# Out:
# ⎡ 11               ⎤
# ⎢ ──    1/25  -9/50⎥
# ⎢ 50               ⎥
# ⎢                  ⎥
# ⎢ 19          -61  ⎥
# ⎢ ──    4/25  ──── ⎥
# ⎢ 50           50  ⎥
# ⎢                  ⎥
# ⎣-3/50  2/25  7/50 ⎦

# %%
from sympy import *
A = Matrix([[1,10,11],[2,20,22],[3,30,33]])
A.det()
# Out:
# 0

# %%
from sympy import *
A = Matrix([[11,12,13],[21,22,23],[31,32,33]])
A.det()
# Out:
# 0

# %%
from sympy import *
A = Matrix([[-1,1],[1,2]])
B = Matrix([[3,2],[1,-2],[0,1]])
a = Matrix([[-1],[2]])
I2 = Matrix([[1,0],[0,1]])

# %%
A * A * A
# Out:
# ⎡-1  4 ⎤
# ⎢      ⎥
# ⎣4   11⎦

# %%
A * B
# Out:
# ---------------------------------------------------------------------------
# ShapeError                                Traceback (most recent call last)
# <ipython-input-33-a4cedde81ed0> in <module>
# ----> 1 A * B
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sympy/core/decorators.py in binary_op_wrapper(self, other)
#     127                     if f is not None:
#     128                         return f(self)
# --> 129             return func(self, other)
#     130         return binary_op_wrapper
#     131     return priority_decorator
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sympy/matrices/common.py in __mul__(self, other)
#    2198         if hasattr(other, 'shape') and len(other.shape) == 2:
#    2199             if self.shape[1] != other.shape[0]:
# -> 2200                 raise ShapeError("Matrix size mismatch: %s * %s." % (
#    2201                     self.shape, other.shape))
#    2202
#
# ShapeError: Matrix size mismatch: (2, 2) * (3, 2).

# %%
B*A
# Out:
# ⎡-1  7 ⎤
# ⎢      ⎥
# ⎢-3  -3⎥
# ⎢      ⎥
# ⎣1   2 ⎦

# %%
A*B.T
# Out:
# ⎡-1  -3  1⎤
# ⎢         ⎥
# ⎣7   -3  2⎦

# %%
B*(A-I2)
# Out:
# ⎡-4  5 ⎤
# ⎢      ⎥
# ⎢-4  -1⎥
# ⎢      ⎥
# ⎣1   1 ⎦

# %%
a.T*A*a
# Out:
# [3]
